# %% [markdown]
# <a href="https://colab.research.google.com/github/iMvijay23/SelfSupervisedNLP/blob/main/Bloom5_5nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q transformers accelerate

# %%
pip install openai

# %%
pip install datasets accelerate

# %%
from datasets import load_dataset

dataset = load_dataset("boolq")
dataset = dataset.shuffle()
train_dataset = dataset["train"][:100]
eval_dataset = dataset["validation"][:100]

# %%
#prompt generation

tc = 0
fc=0
prompt = ""

for sample,l in zip(train_dataset['question'],train_dataset['answer']):
  if l == True :
    if tc<4:
      tc+=1
      prompt+='Question: '+str(sample)+"\t"+"Answer: "+str(l)+"\n"

  elif l == False :
    if fc < 4:
      fc+=1
      prompt+='Question: '+str(sample)+"\t"+"Answer: "+ str(l) +"\n"
  if fc+tc == 8 and fc == tc:
    break

# %%
print(prompt)
# Out:
# Question: do any of the amendments to the u.s. constitution expressly grant individuals the right to privacy	Answer: False
# Question: does a rhombus always have four equal sides	Answer: True
# Question: does nba have one and one free throws	Answer: False
# Question: does system of a down have 2 singers	Answer: True
# Question: can a catholic receive communion in an episcopal church	Answer: False
# Question: was the movie shrek based on a book	Answer: True
# Question: can you jump on free throws in the nba	Answer: True
# Question: is the house on cielo drive still there	Answer: False

# %%
#evaluate prompt
truelabels = []
tc = 0
fc=0
questions = [eval_dataset["question"]]

prompt_template = "Question: {}\nAnswer: "

# %%
print(questions)
# Out:
# [['do ant man and the wasp get together', 'is there any toys r us still open in the world', 'is roman j israel movie based on a true story', 'did top gear really build a bridge over the river', 'do ac milan and inter milan share a stadium', "are there any countries that don't have a football team", 'is precipitation the same as chance of rain', 'can there be a word without a vowel', 'will hawaii five o have a season 8', 'did glenn die in the walking dead season 6', 'do you get money for nobel peace prize', 'is there a six flags in new orleans', 'does a phd give you the title dr', 'is super better than perfect in just dance', 'is france qualified for the world cup 2018', 'is there an interstate that goes coast to coast', 'is the mgm signature attached to the mgm grand', 'does a pdf count as a print source', 'do jj and reid date in criminal minds', 'is american sign language the only sign language', 'is a web server an example of a host', 'do they still make new family guy episodes', 'was the battle of the alamo part of the mexican american war', 'can the speaker of the house be removed', 'do evergreen trees lose their leaves in the winter', 'is cape canaveral the same as the kennedy space center', 'can you get into canada with just a drivers license', 'is discretionary income the same as disposable income', 'do they still make the chrysler pt cruiser', 'is the us postal service part of the federal government', 'is i can only imagine movie true story', 'is the national cathedral in washington dc catholic', 'is secondary school the same as high school in the united states', 'has any nhl team not won the stanley cup', 'is calcium chloride the same as calcium carbonate', 'is a dachshund the same as a sausage dog', 'does winning the fa cup qualify for europe', 'is there a sequel to the whole nine yards', "does charlotte's web cbd oil have thc", 'is there a difference between a confidentiality agreement and a non disclosure agreement', 'did a double deckers have raisins in it', 'will there be a 800 words season 4', 'has anyone won the grand slam in golf', 'do the try guys no longer work for buzzfeed', "is father's day the same day all over the world", 'are there other kinds of ketchup besides tomato', 'is there a difference between hydroxyzine hcl and hydroxyzine pam', 'is there a word where q is not followed by u', 'do they still make philip morris commander cigarettes', 'will being flat footed keep you out of the military', 'does dying light enhanced edition come with the base game', 'is the tv show riverdale based on the archie comics', 'was there a book that predicted the titanic', "does lynette's family die in the tornado", 'can you have more than 2 sets of teeth', 'is it possible to be allergic to rain water', 'did lil dicky write all of freaky friday', 'can you drink alcohol at 16 in australia', 'is guys grocery games in real grocery store', 'is the united states part of the commonwealth of nations', 'do brown recluse spiders live in the woods', 'is a vulture the same as a buzzard', 'does steph curry have a brother that plays basketball', 'has anyone ever died during a football game', 'is canada dry ginger ale made in canada', 'is test track the fastest ride in disney', 'will there be a 7th season of new girl', 'is seagulls stop it now a real song', 'is the league of assassins the same as the league of shadows', 'is there a belt above black in karate', 'is himalayan pink salt the same as curing salt', 'does switzerland allow free movement of eu citizens', 'is it legal to escape from prison in germany', 'is israel part of the european economic area', 'is fullmetal alchemist brotherhood a continuation of the original', 'did they change laurie in that 70s show', 'can a wheel and axle be called a lever', 'was michigan a state during the civil war', 'will there be a season 4 of total bellas', 'do the bruins and celtics play in the same arena', 'is me to we a non profit organization', "is mickey and minnie's house still in magic kin ...

# %%
print(truelabels)
# Out:
# ['True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False']

# %%
# pip install -q transformers
from transformers import AutoModelForCausalLM, AutoTokenizer

checkpoint = "bigscience/bloomz-560m"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint)
# Out:
# Downloading tokenizer.json:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/715 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.12G [00:00<?, ?B/s]

# %%
predlabels=[]
for question in questions[0]:
    prompt = prompt_template.format(question)
    inputs = tokenizer.encode(prompt, return_tensors="pt")
    outputs = model.generate(inputs, max_new_tokens=100)
    generated_text = tokenizer.decode(outputs[0])
    answer = generated_text.split("Answer:")[-1].strip()
    predlabels.append(answer)
    print(f"Question: {question}\nAnswer: {answer}\n")
# Out:
# Question: do ant man and the wasp get together
# Answer: Yes</s>
#
# Question: is there any toys r us still open in the world
# Answer: Yes</s>
#
# Question: is roman j israel movie based on a true story
# Answer: Yes</s>
#
# Question: did top gear really build a bridge over the river
# Answer: Yes</s>
#
# Question: do ac milan and inter milan share a stadium
# Answer: yes</s>
#
# Question: are there any countries that don't have a football team
# Answer: No</s>
#
# Question: is precipitation the same as chance of rain
# Answer: Yes</s>
#
# Question: can there be a word without a vowel
# Answer: ive</s>
#
# Question: will hawaii five o have a season 8
# Answer: Yes</s>
#
# Question: did glenn die in the walking dead season 6
# Answer: Yes</s>
#
# Question: do you get money for nobel peace prize
# Answer: Yes</s>
#
# Question: is there a six flags in new orleans
# Answer: No</s>
#
# Question: does a phd give you the title dr
# Answer: Yes</s>
#
# Question: is super better than perfect in just dance
# Answer: Yes</s>
#
# Question: is france qualified for the world cup 2018
# Answer: Yes</s>
#
# Question: is there an interstate that goes coast to coast
# Answer: Yes</s>
#
# Question: is the mgm signature attached to the mgm grand
# Answer: Yes</s>
#
# Question: does a pdf count as a print source
# Answer: Yes</s>
#
# Question: do jj and reid date in criminal minds
# Answer: Yes</s>
#
# Question: is american sign language the only sign language
# Answer: Yes</s>
#
# Question: is a web server an example of a host
# Answer: Yes</s>
#
# Question: do they still make new family guy episodes
# Answer: yes</s>
#
# Question: was the battle of the alamo part of the mexican american war
# Answer: Yes</s>
#
# Question: can the speaker of the house be removed
# Answer: Yes</s>
#
# Question: do evergreen trees lose their leaves in the winter
# Answer: Yes</s>
#
# Question: is cape canaveral the same as the kennedy space center
# Answer: Yes</s>
#
# Question: can you get into canada with just a drivers license
# Answer: Yes</s>
#
# Question: is discretionary income the same as disposable income
# Answer: Yes</s>
#
# Question: do they still make the chrysler pt cruiser
# Answer: Yes</s>
#
# Question: is the us postal service part of the federal government
# Answer: Yes</s>
#
# Question: is i can only imagine movie true story
# Answer: Yes</s>
#
# Question: is the national cathedral in washington dc catholic
# Answer: Yes</s>
#
# Question: is secondary school the same as high school in the united states
# Answer: Yes</s>
#
# Question: has any nhl team not won the stanley cup
# Answer: Yes</s>
#
# Question: is calcium chloride the same as calcium carbonate
# Answer: Yes</s>
#
# Question: is a dachshund the same as a sausage dog
# Answer: Yes</s>
#
# Question: does winning the fa cup qualify for europe
# Answer: Yes</s>
#
# Question: is there a sequel to the whole nine yards
# Answer: Yes</s>
#
# Question: does charlotte's web cbd oil have thc
# Answer: Yes</s>
#
# Question: is there a difference between a confidentiality agreement and a non disclosure agreement
# Answer: Yes</s>
#
# Question: did a double deckers have raisins in it
# Answer: Yes</s>
#
# Question: will there be a 800 words season 4
# Answer: Yes</s>
#
# Question: has anyone won the grand slam in golf
# Answer: Yes</s>
#
# Question: do the try guys no longer work for buzzfeed
# Answer: no</s>
#
# Question: is father's day the same day all over the world
# Answer: Yes</s>
#
# Question: are there other kinds of ketchup besides tomato
# Answer: no</s>
#
# Question: is there a difference between hydroxyzine hcl and hydroxyzine pam
# Answer: Yes</s>
#
# Question: is there a word where q is not followed by u
# Answer: ũ</s>
#
# Question: do they still make philip morris commander cigarettes
# Answer: Yes</s>
#
# Question: will being flat footed keep you out of the military
# Answer: Yes</s>
#
# Question: does dying light enhanced edition come with the base game
# Answer: Yes</s>
#
# Question: is the tv show riverdale based on the archie comics
# Answer: Yes</s>
#
# Question: was there a book that predicted the titanic
# Answer: Yes</s>
#
# Question: does lynette's family die in the tornado
# Answer: Yes</s>
#
# Question: can you have more than 2 sets of teeth
# Answer: Yes</s>
#
# Question: is it possible to be allergic to rain water
# Answer: Yes</s>
#
# Question: did lil dicky write all of freaky friday
# Answer: Yes</s>
#
# Question: can you drink alcohol at 16 in australia
# Answer: Yes</s>
#
# Question: is guys grocery games in real grocery store
# Answer: No</s>
#
# Question: is the united states part of the commonwealth of nations
# Answer: Yes</s>
#
# Question: do brown recluse spiders live in the woods
# Answer: Yes</s>
#
# Question: is a vulture the same as a buzzard
# Answer: Yes</s>
#
# Question: does steph curry have a brother that plays basketball
# Answer: Yes</s>
#
# Question: has anyone ever died during a football game
# Answer: Yes</s>
#
# Question: is canada dry ginger ale made in canada
# Answer: Yes</s>
#
# Question: is test track the fastest ride in disney
# Answer: Yes</s>
#
# Question: will there be a 7th season of new girl
# Answer: Yes</s>
#
# Question: is seagulls stop it now a real song
# Answer: No</s>
#
# Question: is the league of assassins the same as the league of shadows
# Answer: No</s>
#
# Question: is there a belt above black in karate
# Answer: Yes</s>
#
# Question: is himalayan pink salt the same as curing salt
# Answer: Yes</s>
#
# Question: does switzerland allow free movement of eu citizens
# Answer: Yes</s>
#
# Question: is it legal to escape from prison in germany
# Answer: Yes</s>
#
# Question: is israel part of the european economic area
# Answer: Yes</s>
#
# Question: is fullmetal alchemist brotherhood a continuation of the original
# Answer: Yes</s>
#
# Question: did they change laurie in that 70s show
# Answer: Yes</s>
#
# Question: can a wheel and axle be called a lever
# Answer: Yes</s>
#
# Question: was michigan a state during the civil war
# Answer: Yes</s>
#
# Question: will there be a season 4 of total bellas
# Answer: Yes</s>
#
# Question: do the bruins and celtics play in the same arena
# Answer: Yes</s>
#
# Question: is me to we a non profit organization
# Answer: Yes</s>
#
# Question: is mickey and minnie's house still in magic kingdom
# Answer: Yes</s>
#
# Question: do i use plumbers tape on compression fittings
# Answer: Yes</s>
#
# Question: is avicii the guy in the nights video
# Answer: Yes</s>
#
# Question: can pool water change color if you pee in it
# Answer: Yes</s>
#
# Question: are there confederate soldiers buried in arlington national cemetery
# Answer: Yes</s>
#
# Question: is there sales tax on crv in california
# Answer: Yes</s>
#
# Question: is there a camera on all traffic lights
# Answer: Yes</s>
#
# Question: are there internet cables under the atlantic ocean
# Answer: Yes</s>
#
# Question: can you buy beer on easter sunday in kansas
# Answer: Yes</s>
#
# Question: is area code 669 a toll free number
# Answer: Yes</s>
#
# Question: can you travel internationally with a passport card
# Answer: Yes</s>
#
# Question: is it a requirement to own a gun in switzerland
# Answer: Yes</s>
#
# Question: does her dad die in the last song
# Answer: Yes</s>
#
# Question: can you build up immunity to snake venom
# Answer: Yes</s>
#
# Question: can a puerto rican resident vote for president
# Answer: Yes</s>
#
# Question: is a cougar and a mountain lion the same
# Answer: No</s>
#
# Question: is it bad to wash your hair with shower gel
# Answer: Yes</s>
#
# Question: does a conditional discharge mean a criminal record
# Answer: Yes</s>
#
# Question: can a soft material scratch a hard material
# Answer: Yes</s>
